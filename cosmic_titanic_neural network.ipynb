# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import seaborn as sns

# %%
train_set = pd.read_csv(r'C:\Users\Ismat\OneDrive\Рабочий стол\document\etc\lesson_course\projects\cosmic_disaster\train.csv')
test_set = pd.read_csv(r'C:\Users\Ismat\OneDrive\Рабочий стол\document\etc\lesson_course\projects\cosmic_disaster\test.csv')

# %%
train_set['Transported'][train_set['Transported']==True]=1
train_set['Transported'][train_set['Transported']==False]=0

features=['HomePlanet','CryoSleep','Destination','Age','VIP','RoomService','FoodCourt','ShoppingMall','Spa','VRDeck']
target = ['Transported']

train_set_featured=pd.get_dummies(train_set[features])
from sklearn.impute import KNNImputer
imputer = KNNImputer()
train_imputed=imputer.fit_transform(train_set_featured)
train_imputed=pd.DataFrame(train_imputed)

test_set_featured=pd.get_dummies(test_set[features])
from sklearn.impute import KNNImputer
imputer = KNNImputer()
test_imputed=imputer.fit_transform(test_set_featured)
test_imputed=pd.DataFrame(test_imputed)

X = train_imputed
y = train_set[target].astype('int')
prediction=test_imputed

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 47)

from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
scaled_prediction=sc.fit_transform(prediction)
# Out:
# C:\Users\Ismat\AppData\Local\Temp\ipykernel_8204\3672547886.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_set['Transported'][train_set['Transported']==True]=1

# %%
def batch(n):
    l=[]
    for i in range (1,n+1):
        if n%i==0:
            l+=[i]
    return l;
batch(8692)
# Out:
# [1, 2, 4, 41, 53, 82, 106, 164, 212, 2173, 4346, 8692]

# %%
# %%time
import tensorflow as tf
ann = tf.keras.models.Sequential()

ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

ann.add(tf.keras.layers.Dense(units=3, activation='relu'))

# ann.add(tf.keras.layers.Dense(units=3, activation='relu'))

# ann.add(tf.keras.layers.Dense(units=3, activation='relu'))

# ann.add(tf.keras.layers.Dense(units=3, activation='relu'))

ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

ann.compile(optimizer = 'Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

ann.fit(X_train, y_train, batch_size = 164, epochs =100 )
# Out:
# Epoch 1/100
# 40/40 [==============================] - 0s 939us/step - loss: 0.7334 - accuracy: 0.5019
# Epoch 2/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.6932 - accuracy: 0.5030
# Epoch 3/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.6617 - accuracy: 0.5058
# Epoch 4/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.6307 - accuracy: 0.5946
# Epoch 5/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.6062 - accuracy: 0.6891
# Epoch 6/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5932 - accuracy: 0.7073
# Epoch 7/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5848 - accuracy: 0.7151
# Epoch 8/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5787 - accuracy: 0.7158
# Epoch 9/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5739 - accuracy: 0.7168
# Epoch 10/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5701 - accuracy: 0.7170
# Epoch 11/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5669 - accuracy: 0.7173
# Epoch 12/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5643 - accuracy: 0.7173
# Epoch 13/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5623 - accuracy: 0.7173
# Epoch 14/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5602 - accuracy: 0.7173
# Epoch 15/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5587 - accuracy: 0.7174
# Epoch 16/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5574 - accuracy: 0.7179
# Epoch 17/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5563 - accuracy: 0.7185
# Epoch 18/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5552 - accuracy: 0.7190
# Epoch 19/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5544 - accuracy: 0.7191
# Epoch 20/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5538 - accuracy: 0.7199
# Epoch 21/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5528 - accuracy: 0.7202
# Epoch 22/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5519 - accuracy: 0.7210
# Epoch 23/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5512 - accuracy: 0.7219
# Epoch 24/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5504 - accuracy: 0.7224
# Epoch 25/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5496 - accuracy: 0.7231
# Epoch 26/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5484 - accuracy: 0.7289
# Epoch 27/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5451 - accuracy: 0.7273
# Epoch 28/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5435 - accuracy: 0.7309
# Epoch 29/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5420 - accuracy: 0.7332
# Epoch 30/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5407 - accuracy: 0.7345
# Epoch 31/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5396 - accuracy: 0.7362
# Epoch 32/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5385 - accuracy: 0.7423
# Epoch 33/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5372 - accuracy: 0.7451
# Epoch 34/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5362 - accuracy: 0.7452
# Epoch 35/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5352 - accuracy: 0.7449
# Epoch 36/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5342 - accuracy: 0.7484
# Epoch 37/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5333 - accuracy: 0.7466
# Epoch 38/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5324 - accuracy: 0.7475
# Epoch 39/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5317 - accuracy: 0.7470
# Epoch 40/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5309 - accuracy: 0.7487
# Epoch 41/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5305 - accuracy: 0.7478
# Epoch 42/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5297 - accuracy: 0.7467
# Epoch 43/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5290 - accuracy: 0.7478
# Epoch 44/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5286 - accuracy: 0.7480
# Epoch 45/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5279 - accuracy: 0.7467
# Epoch 46/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5262 - accuracy: 0.7477
# Epoch 47/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5241 - accuracy: 0.7472
# Epoch 48/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5227 - accuracy: 0.7472
# Epoch 49/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5213 - accuracy: 0.7486
# Epoch 50/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5192 - accuracy: 0.7489
# Epoch 51/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5168 - accuracy: 0.7483
# Epoch 52/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5138 - accuracy: 0.7484
# Epoch 53/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5103 - accuracy: 0.7492
# Epoch 54/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5073 - accuracy: 0.7570
# Epoch 55/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5039 - accuracy: 0.7627
# Epoch 56/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5000 - accuracy: 0.7650
# Epoch 57/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4976 - accuracy: 0.7659
# Epoch 58/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4954 - accuracy: 0.7682
# Epoch 59/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4929 - accuracy: 0.7701
# Epoch 60/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4912 - accuracy: 0.7734
# Epoch 61/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4887 - accuracy: 0.7702
# Epoch 62/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4868 - accuracy: 0.7710
# Epoch 63/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4850 - accuracy: 0.7722
# Epoch 64/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4827 - accuracy: 0.7742
# Epoch 65/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4800 - accuracy: 0.7751
# Epoch 66/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4778 - accuracy: 0.7790
# Epoch 67/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4762 - accuracy: 0.7793
# Epoch 68/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4744 - accuracy: 0.7808
# Epoch 69/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4730 - accuracy: 0.7811
# Epoch 70/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4719 - accuracy: 0.7796
# Epoch 71/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4701 - accuracy: 0.7825
# Epoch 72/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4695 - accuracy: 0.7806
# Epoch 73/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4680 - accuracy: 0.7826
# Epoch 74/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4669 - accuracy: 0.7816
# Epoch 75/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4654 - accuracy: 0.7843
# Epoch 76/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4643 - accuracy: 0.7825
# Epoch 77/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4646 - accuracy: 0.7837
# Epoch 78/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4628 - accuracy: 0.7832
# Epoch 79/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4616 - accuracy: 0.7843
# Epoch 80/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4611 - accuracy: 0.7814
# Epoch 81/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7845
# Epoch 82/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4590 - accuracy: 0.7828
# Epoch 83/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4578 - accuracy: 0.7848
# Epoch 84/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4572 - accuracy: 0.7834
# Epoch 85/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4562 - accuracy: 0.7852
# Epoch 86/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4554 - accuracy: 0.7869
# Epoch 87/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4542 - accuracy: 0.7848
# Epoch 88/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4543 - accuracy: 0.7859
# Epoch 89/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4533 - accuracy: 0.7851
# Epoch 90/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4528 - accuracy: 0.7860
# Epoch 91/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4519 - accuracy: 0.7855
# Epoch 92/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4519 - accuracy: 0.7849
# Epoch 93/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4508 - accuracy: 0.7845
# Epoch 94/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4504 - accuracy: 0.7854
# Epoch 95/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4501 - accuracy: 0.7885
# Epoch 96/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4499 - accuracy: 0.7845
# Epoch 97/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4490 - accuracy: 0.7859
# Epoch 98/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4489 - accuracy: 0.7848
# Epoch 99/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4480 - accuracy: 0.7849
# Epoch 100/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4482 - accuracy: 0.7842
# CPU times: total: 25.6 s
# Wall time: 5.33 s

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report

ann_prediction = ann.predict(X_test)

ann_prediction = (ann_prediction > 0.5)

submission=ann.predict(scaled_prediction)

submission = (submission > 0.5)

# output = pd.DataFrame({'PassengerId': data_frame_test.PassengerId, 'Survived':  list(np.array(submission))})

# output['Survived'][output['Survived']==True]=1

# output['Survived'][output['Survived']==False]=0

# output.to_csv('ann.csv', index=False)

# print("Your submission was successfully saved!")

# print(accuracy_score(y_test, ann_prediction))

print(classification_report(y_test, ann_prediction))
# Out:
# 68/68 [==============================] - 0s 716us/step
# 134/134 [==============================] - 0s 722us/step
#               precision    recall  f1-score   support
#
#            0       0.82      0.77      0.80      1077
#            1       0.79      0.84      0.81      1097
#
#     accuracy                           0.80      2174
#    macro avg       0.81      0.80      0.80      2174
# weighted avg       0.81      0.80      0.80      2174

# %%
output = pd.DataFrame({'PassengerId': test_set.PassengerId, 'Transported':  np.ravel(submission)})

# output = pd.DataFrame({'PassengerId': test_set.PassengerId, 'Transported': submission})

# output['Transported'][output['Transported']==1]=True
# output['Transported'][output['Transported']==0]=False
output
# Out:
#      PassengerId  Transported
# 0        0013_01         True
# 1        0018_01        False
# 2        0019_01         True
# 3        0021_01         True
# 4        0023_01         True
# ...          ...          ...
# 4272     9266_02         True
# 4273     9269_01        False
# 4274     9271_01         True
# 4275     9273_01         True
# 4276     9277_01         True
#
# [4277 rows x 2 columns]

# %%
output.to_csv('ANN.csv', index=False)
